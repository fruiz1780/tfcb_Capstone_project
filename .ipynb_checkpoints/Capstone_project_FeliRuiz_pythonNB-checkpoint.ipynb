# %% [markdown]
# ## Capstone Project, Hw8.
# #### Felicitas Ruiz
# #### TFCB_2020

# %% [markdown]
# ###### Data
# Link to data

# %% [markdown]
# ### Questions that I will ask in Python
# ###### 2. Continung with the theme of gender differences within disease groups, I wanted to see if there are also differences in care. For instance, are males more likely to receive chemotherapy than females in each adenocarcinoma disease group and in the hepatocellular carcinoma group? I will answer this question in Python.

# %%
#First start by importing pandas
import pandas as pd

# %%
# Read in files from Fisher's famous iris dataset, which contains anatomical data on a variety of flowers
# read_csv returns a pandas dataframe

#Full_pcbil_raw = pd.read_csv('data/pcbil_raw.csv')
#pcbil_clinicaldata_patientdata_messy = pd.read_csv('data/pcbil_clinicaldata_patientdata_cleanup.csv')
Filtered = pd.read_csv('data/pcbil_clinicaldata_PLOS_REVISION.csv')

# %%
Filtered.head(10)
# Out:
#               pad person_number_anon  date_birth gender chemo    date_pad  \
# 0  Ampulla Ac|124                PN1    3/5/1936      m     y   4/26/2005
# 1  Ampulla Ac|173                PN2  11/10/1939      m     y   1/21/2010
# 2  Ampulla Ac|177                PN3   5/27/1917      f   NaN   9/20/2005
# 3  Ampulla Ac|200                PN4   5/29/1932      f     n    2/9/2012
# 4  Ampulla Ac|225                PN5  11/23/1936      m     n   4/18/2011
# 5  Ampulla Ac|235                PN6  11/23/1931      m   NaN    5/6/2009
# 6  Ampulla Ac|237                PN7    6/5/1955      f     y   4/14/2008
# 7  Ampulla Ac|241                PN8   8/11/1969      m     y   6/18/2009
# 8  Ampulla Ac|254                PN9    1/1/1973      m     n  10/26/2009
# 9  Ampulla Ac|262               PN10  10/17/1923      f     n   8/27/2002
#
#   type_probe  p_r  p_t  p_n  p_m  p_l  p_v  p_pn  date_death  comments
# 0          r  0.0    3    1  NaN  NaN  NaN   NaN   4/13/2007       NaN
# 1          r  0.0    1    0    x    1    0   NaN   8/30/2012       NaN
# 2          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   5/28/2006       NaN
# 3          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  12/16/2012       NaN
# 4          r  0.0    2    0    x    1    0   NaN   8/14/2011       NaN
# 5          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   5/11/2009       NaN
# 6          r  NaN    1    0  NaN  NaN  NaN   NaN    2/3/2010       NaN
# 7          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  11/22/2010       NaN
# 8          r  0.0    3    1    x    0    0   NaN         NaN       NaN
# 9          r  NaN    3    0    x  NaN  NaN   NaN    8/7/2014       NaN

# %%
#Here I am creating a dataframe from the read csv file
filter_df = pd.DataFrame(Filtered)

# %%
#WHAT I did here is split the objects in the pad column so that I could manipulate the data by disease
pad_column=filter_df["pad"]
#pad_column

pad_only_list=[]
pad_number_list=[]
for item in filter_df["pad"]:
    new_item=item.split("|")
    pad_only=new_item[0]
    pad_number=new_item[1]
    pad_only_list.append(pad_only)
    pad_number_list.append(pad_number)
#pad_number_list 
#pad_only_list

filter_df
# Out:
#                    pad person_number_anon  date_birth gender chemo  \
# 0       Ampulla Ac|124                PN1    3/5/1936      m     y
# 1       Ampulla Ac|173                PN2  11/10/1939      m     y
# 2       Ampulla Ac|177                PN3   5/27/1917      f   NaN
# 3       Ampulla Ac|200                PN4   5/29/1932      f     n
# 4       Ampulla Ac|225                PN5  11/23/1936      m     n
# ..                 ...                ...         ...    ...   ...
# 386  Perihilary Ac|419              PN359   12/8/1975      m   NaN
# 387  Perihilary Ac|437              PN360   2/17/1932      f     n
# 388    Perihilary Ac|6              PN361   4/13/1957      f     n
# 389    Perihilary Ac|7              PN361   4/13/1957      f     n
# 390    Perihilary Ac|9              PN362   11/7/1944      m     y
#
#        date_pad type_probe  p_r  p_t  p_n  p_m  p_l  p_v  p_pn  date_death  \
# 0     4/26/2005          r  0.0    3    1  NaN  NaN  NaN   NaN   4/13/2007
# 1     1/21/2010          r  0.0    1    0    x    1    0   NaN   8/30/2012
# 2     9/20/2005          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   5/28/2006
# 3      2/9/2012          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  12/16/2012
# 4     4/18/2011          r  0.0    2    0    x    1    0   NaN   8/14/2011
# ..          ...        ...  ...  ...  ...  ...  ...  ...   ...         ...
# 386   6/27/2011          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   7/20/2012
# 387  12/10/2008          r  0.0    3    x    x    0    0   NaN         NaN
# 388  11/28/2011          r  0.0    2    0  NaN    0    0   1.0         NaN
# 389  11/28/2011          r  0.0    2    0  NaN    0    0   1.0         NaN
# 390   10/7/2009          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  12/14/2013
#
#      comments
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 386       NaN
# 387       NaN
# 388       NaN
# 389       NaN
# 390       NaN
#
# [391 rows x 16 columns]

# %%
#Now I am adding the list of disease and number associate with that disease to a separate column
filter_df["pad_only"]=pad_only_list
filter_df["pad_number"]=pad_number_list

# %%
#Now that I added both the disease("pad_only") and pad number, I will drop the "pad" column
New_filter_df=filter_df.drop(columns=['pad'])
New_filter_df
# Out:
#     person_number_anon  date_birth gender chemo    date_pad type_probe  p_r  \
# 0                  PN1    3/5/1936      m     y   4/26/2005          r  0.0
# 1                  PN2  11/10/1939      m     y   1/21/2010          r  0.0
# 2                  PN3   5/27/1917      f   NaN   9/20/2005          b  NaN
# 3                  PN4   5/29/1932      f     n    2/9/2012          b  NaN
# 4                  PN5  11/23/1936      m     n   4/18/2011          r  0.0
# ..                 ...         ...    ...   ...         ...        ...  ...
# 386              PN359   12/8/1975      m   NaN   6/27/2011          b  NaN
# 387              PN360   2/17/1932      f     n  12/10/2008          r  0.0
# 388              PN361   4/13/1957      f     n  11/28/2011          r  0.0
# 389              PN361   4/13/1957      f     n  11/28/2011          r  0.0
# 390              PN362   11/7/1944      m     y   10/7/2009          b  NaN
#
#      p_t  p_n  p_m  p_l  p_v  p_pn  date_death  comments       pad_only  \
# 0      3    1  NaN  NaN  NaN   NaN   4/13/2007       NaN     Ampulla Ac
# 1      1    0    x    1    0   NaN   8/30/2012       NaN     Ampulla Ac
# 2    NaN  NaN  NaN  NaN  NaN   NaN   5/28/2006       NaN     Ampulla Ac
# 3    NaN  NaN  NaN  NaN  NaN   NaN  12/16/2012       NaN     Ampulla Ac
# 4      2    0    x    1    0   NaN   8/14/2011       NaN     Ampulla Ac
# ..   ...  ...  ...  ...  ...   ...         ...       ...            ...
# 386  NaN  NaN  NaN  NaN  NaN   NaN   7/20/2012       NaN  Perihilary Ac
# 387    3    x    x    0    0   NaN         NaN       NaN  Perihilary Ac
# 388    2    0  NaN    0    0   1.0         NaN       NaN  Perihilary Ac
# 389    2    0  NaN    0    0   1.0         NaN       NaN  Perihilary Ac
# 390  NaN  NaN  NaN  NaN  NaN   NaN  12/14/2013       NaN  Perihilary Ac
#
#     pad_number
# 0          124
# 1          173
# 2          177
# 3          200
# 4          225
# ..         ...
# 386        419
# 387        437
# 388          6
# 389          7
# 390          9
#
# [391 rows x 17 columns]

# %%
chemo_new=[]
l_new=['N/A' if x is np.nan else x for x in New_filter_df["chemo"]]
        
for items in l_new:

    if items == "Y":
        chemo_new.append(1)
    elif items == "y":
        chemo_new.append(1)
    else:
        chemo_new.append(0)
   # print(items)
#chemo_new

New_filter_df["Chemo (Yes=1, No or unknown=0)"]=chemo_new
New_filter_df_for_chemo=New_filter_df.drop(columns=['chemo'])

# %%
New_filter_df_for_chemo
# Out:
#     person_number_anon  date_birth gender    date_pad type_probe  p_r  p_t  \
# 0                  PN1    3/5/1936      m   4/26/2005          r  0.0    3
# 1                  PN2  11/10/1939      m   1/21/2010          r  0.0    1
# 2                  PN3   5/27/1917      f   9/20/2005          b  NaN  NaN
# 3                  PN4   5/29/1932      f    2/9/2012          b  NaN  NaN
# 4                  PN5  11/23/1936      m   4/18/2011          r  0.0    2
# ..                 ...         ...    ...         ...        ...  ...  ...
# 386              PN359   12/8/1975      m   6/27/2011          b  NaN  NaN
# 387              PN360   2/17/1932      f  12/10/2008          r  0.0    3
# 388              PN361   4/13/1957      f  11/28/2011          r  0.0    2
# 389              PN361   4/13/1957      f  11/28/2011          r  0.0    2
# 390              PN362   11/7/1944      m   10/7/2009          b  NaN  NaN
#
#      p_n  p_m  p_l  p_v  p_pn  date_death  comments       pad_only pad_number  \
# 0      1  NaN  NaN  NaN   NaN   4/13/2007       NaN     Ampulla Ac        124
# 1      0    x    1    0   NaN   8/30/2012       NaN     Ampulla Ac        173
# 2    NaN  NaN  NaN  NaN   NaN   5/28/2006       NaN     Ampulla Ac        177
# 3    NaN  NaN  NaN  NaN   NaN  12/16/2012       NaN     Ampulla Ac        200
# 4      0    x    1    0   NaN   8/14/2011       NaN     Ampulla Ac        225
# ..   ...  ...  ...  ...   ...         ...       ...            ...        ...
# 386  NaN  NaN  NaN  NaN   NaN   7/20/2012       NaN  Perihilary Ac        419
# 387    x    x    0    0   NaN         NaN       NaN  Perihilary Ac        437
# 388    0  NaN    0    0   1.0         NaN       NaN  Perihilary Ac          6
# 389    0  NaN    0    0   1.0         NaN       NaN  Perihilary Ac          7
# 390  NaN  NaN  NaN  NaN   NaN  12/14/2013       NaN  Perihilary Ac          9
#
#      Chemo (Yes=1, No or unknown=0)
# 0                                 1
# 1                                 1
# 2                                 0
# 3                                 0
# 4                                 0
# ..                              ...
# 386                               0
# 387                               0
# 388                               0
# 389                               0
# 390                               1
#
# [391 rows x 17 columns]

# %% [markdown]
# ## Here is where I will actually group by gender and count the number of patients that received chemo based on gender

# %%
Gender_chemo_by_disease=New_filter_df_for_chemo.groupby(["pad_only", "gender", "Chemo (Yes=1, No or unknown=0)"]).size()

Gender_chemo_by_disease
# Out:
# pad_only                         gender  Chemo (Yes=1, No or unknown=0)
# Ampulla Ac                       f       0                                  7
#                                          1                                  5
#                                  m       0                                  5
#                                          1                                  6
# Distal Bile Duct Ac              f       0                                  1
#                                          1                                  1
#                                  m       0                                  2
#                                          1                                  2
# Gallbladder Ac                   f       0                                 16
#                                          1                                 10
#                                  m       0                                  4
#                                          1                                  4
# Hepatocellular Cancer            f       0                                 11
#                                          1                                  2
#                                  m       0                                 54
#                                          1                                  8
# Intrahepatic Cholangiocarcinoma  f       0                                 24
#                                          1                                 31
#                                  m       0                                 25
#                                          1                                 18
# Pancreas Ac                      f       0                                 38
#                                          1                                 27
#                                  m       0                                 28
#                                          1                                 36
# Perihilary Ac                    f       0                                 10
#                                          1                                  5
#                                  m       0                                  5
#                                          1                                  6
# dtype: int64

# %%
f_ratio= 2/11
f_ratio
# Out:
# 0.18181818181818182

# %%
m_ratio=8/54
m_ratio
# Out:
# 0.14814814814814814

# %%
import matplotlib.pyplot as plt

Gender_chemo_by_disease.plot.bar(color=['black', 'black', 'black', 'black', 
                                        'red', 'red', 'red', 'red',
                                        'green','green', 'green', 'green',
                                        'blue', 'blue', 'blue', 'blue',
                                       'cyan', 'cyan', 'cyan', 'cyan',
                                       'pink', 'pink', 'pink', 'pink',
                                       'purple', 'purple', 'purple', 'purple',])
plt.title('Patients receiving chemotherapy grouped by disease and gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# So here I will answer problem 2. I created a graph above called 'Patients receiving chemotherapy grouped by disease and gender'. By looking at the graph, we can see that in most cases, the number of patients that received chemotherapy based on gender within a disease group is pretty even. By this, I mean that females that do not receive chemotherapy in the Ampulla Adenocarcinoma disease group (indicated by "Ampulla Ac, f, 0") is about the same as those females that do (indicated by "Ampulla Ac, f, 1") and is also comparable to males that do not receive chemo (indicated by "Ampulla Ac, m, 0") and males that do receive chemo (indicated by "Ampulla Ac, m, 1").

# %% [markdown]
# But there are instances where this is not the case. For instance, in the Hepatocellular cancer group, there are more males that do not receive chemo (indicated by "Hepatocellular Cancer, m, 0") than males that do receive chemo (indicated by "Hepatocellular Cancer, m, 0"). There are also more females that do not receive chemo (indicated by "Hepatocellular Cancer, f, 0") than females that do receive chemo therapy. Compared to males, the ratio of females that do receive chemo to those that don't  is about the same ratio.
# Overall, there does not appear to be major differences in those that do and don't receive chemotherapy based on gender and within each disease group.

# %% [markdown]
# #Here I wanted to add age column to my dataset for problem 1 in R. But I didn't know quite how to do it in R so I did it in python. I then saved the new datset that now has a new column to a 'Filtered_edit_df.csv'

# %%
Filtered_edited = pd.read_csv('data/pcbil_clinicaldata_PLOS_REVISION_edited.csv')
Filtered_edit_df= pd.DataFrame(Filtered_edited)
lengthy=len(Filtered_edit_df["date_birth"])


import datetime
import dateutil

# %%
birth_list=[]
for date in Filtered_edit_df["date_birth"]:
    numba=date.split("/")
    birth_date = datetime.date(int(numba[2]), int(numba[0]), int(numba[1]))
    birth_list.append(birth_date)

# %%
death_list=[]
for Dx in Filtered_edit_df["date_death"]:
    if Dx != "Present":
        numba2=Dx.split("/")
        end_date = datetime.date(int(numba2[2]), int(numba2[0]), int(numba2[1]))
        
    else:
        end_date = datetime.date(2016, 8, 1)
        
    death_list.append(end_date)

# %%
time_difference_list=[]
for counting in range(lengthy):
    time_difference=death_list[counting] - birth_list[counting]
    age = time_difference.days
    time_difference_list.append(age)

# %%
Filtered_edit_df["Age (in days)"]=time_difference_list
Filtered_edit_df

# %%
Filtered_edit_df["pad_only"]=pad_only_list
Filtered_edit_df["pad_number"]=pad_number_list

# %%
Filtered_edit_df
# Out:
#                    pad person_number_anon  date_birth gender chemo  \
# 0       Ampulla Ac|124                PN1    3/5/1936      m     y
# 1       Ampulla Ac|173                PN2  11/10/1939      m     y
# 2       Ampulla Ac|177                PN3   5/27/1917      f   NaN
# 3       Ampulla Ac|200                PN4   5/29/1932      f     n
# 4       Ampulla Ac|225                PN5  11/23/1936      m     n
# ..                 ...                ...         ...    ...   ...
# 386  Perihilary Ac|419              PN359   12/8/1975      m   NaN
# 387  Perihilary Ac|437              PN360   2/17/1932      f     n
# 388    Perihilary Ac|6              PN361   4/13/1957      f     n
# 389    Perihilary Ac|7              PN361   4/13/1957      f     n
# 390    Perihilary Ac|9              PN362   11/7/1944      m     y
#
#        date_pad type_probe  p_r  p_t  p_n  p_m  p_l  p_v  p_pn  date_death  \
# 0     4/26/2005          r  0.0    3    1  NaN  NaN  NaN   NaN   4/13/2007
# 1     1/21/2010          r  0.0    1    0    x    1    0   NaN   8/30/2012
# 2     9/20/2005          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   5/28/2006
# 3      2/9/2012          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  12/16/2012
# 4     4/18/2011          r  0.0    2    0    x    1    0   NaN   8/14/2011
# ..          ...        ...  ...  ...  ...  ...  ...  ...   ...         ...
# 386   6/27/2011          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN   7/20/2012
# 387  12/10/2008          r  0.0    3    x    x    0    0   NaN     Present
# 388  11/28/2011          r  0.0    2    0  NaN    0    0   1.0     Present
# 389  11/28/2011          r  0.0    2    0  NaN    0    0   1.0     Present
# 390   10/7/2009          b  NaN  NaN  NaN  NaN  NaN  NaN   NaN  12/14/2013
#
#      comments  Age (in days)       pad_only pad_number
# 0         NaN          25971     Ampulla Ac        124
# 1         NaN          26592     Ampulla Ac        173
# 2         NaN          32508     Ampulla Ac        177
# 3         NaN          29421     Ampulla Ac        200
# 4         NaN          27292     Ampulla Ac        225
# ..        ...            ...            ...        ...
# 386       NaN          13374  Perihilary Ac        419
# 387       NaN          30847  Perihilary Ac        437
# 388       NaN          21660  Perihilary Ac          6
# 389       NaN          21660  Perihilary Ac          7
# 390       NaN          25239  Perihilary Ac          9
#
# [391 rows x 19 columns]

# %%
import numpy as np
#numpy_array = Filtered_edit_df.to_numpy()
#np.savetxt("Filtered_edit_df.txt", numpy_array, fmt = "%d")

Filtered_edit_df.to_csv(r'data/Filtered_edit_df.csv', index = False)
